# %%
import pandas as pd
data=pd.read_csv('C:/Users/Deva Adithya/Downloads/Career project semi/Career project/MINI_Project dataset.csv',encoding='windows-1254')
data.head(10)
# Out:
#        school Inter/Polytechnic/CBSE Board/ITI/Paramedical  \
# 0  10th Board                    10th Board - Intermediate
# 1  10th Board                    10th Board - Intermediate
# 2  10th Board                    10th Board - Intermediate
# 3  10th Board                    10th Board - Intermediate
# 4  10th Board                    10th Board - Intermediate
# 5  10th Board                    10th Board - Intermediate
# 6  10th Board                    10th Board - Intermediate
# 7  10th Board                    10th Board - Intermediate
# 8  10th Board                    10th Board - Intermediate
# 9  10th Board                    10th Board - Intermediate
#
#                                                Group  \
# 0  10th Board - Intermediate - MPC(Maths, Physics...
# 1  10th Board - Intermediate - MPC(Maths, Physics...
# 2  10th Board - Intermediate - MPC(Maths, Physics...
# 3  10th Board - Intermediate - MPC(Maths, Physics...
# 4  10th Board - Intermediate - MPC(Maths, Physics...
# 5  10th Board - Intermediate - MPC(Maths, Physics...
# 6  10th Board - Intermediate - MPC(Maths, Physics...
# 7  10th Board - Intermediate - MPC(Maths, Physics...
# 8  10th Board - Intermediate - MPC(Maths, Physics...
# 9  10th Board - Intermediate - MPC(Maths, Physics...
#
#                                               Degree  \
# 0  10th Board - Intermediate - MPC(Maths, Physics...
# 1  10th Board - Intermediate - MPC(Maths, Physics...
# 2  10th Board - Intermediate - MPC(Maths, Physics...
# 3  10th Board - Intermediate - MPC(Maths, Physics...
# 4  10th Board - Intermediate - MPC(Maths, Physics...
# 5  10th Board - Intermediate - MPC(Maths, Physics...
# 6  10th Board - Intermediate - MPC(Maths, Physics...
# 7  10th Board - Intermediate - MPC(Maths, Physics...
# 8  10th Board - Intermediate - MPC(Maths, Physics...
# 9  10th Board - Intermediate - MPC(Maths, Physics...
#
#                                      Branches/Course  \
# 0  10th Board - Intermediate - MPC(Maths, Physics...
# 1  10th Board - Intermediate - MPC(Maths, Physics...
# 2  10th Board - Intermediate - MPC(Maths, Physics...
# 3  10th Board - Intermediate - MPC(Maths, Physics...
# 4  10th Board - Intermediate - MPC(Maths, Physics...
# 5  10th Board - Intermediate - MPC(Maths, Physics...
# 6  10th Board - Intermediate - MPC(Maths, Physics...
# 7  10th Board - Intermediate - MPC(Maths, Physics...
# 8  10th Board - Intermediate - MPC(Maths, Physics...
# 9  10th Board - Intermediate - MPC(Maths, Physics...
#
#                                               Output
# 0  Jobs: Racing Car Designer, Flight Mechanics En...
# 1  Jobs: Executive and Managerial Positions, Driv...
# 2  Jobs: Civil Engineer, Transportation Engineer,...
# 3  Jobs: data scientist, computer programmer, sys...
# 4  Jobs: Data scientist, Data Architect, Data Sci...
# 5  Jobs: Machine Learning Engineer, Data Scientis...
# 6  Jobs: Robotics Engineer, Robotics analyst and ...
# 7  Jobs: Software architect, Development operatio...
# 8  Jobs: Computer Network Support Specialist, Com...
# 9  Jobs: Cyber Forensics Solutions architect, Mal...

# %%
data.shape
# Out:
# (717, 6)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data.iloc[:,0:5],data.iloc[:,5],test_size=0.2)

# %%
from sklearn.preprocessing import LabelEncoder

label= LabelEncoder()
x_train=data.iloc[:,:].values
x_train[:,5]=label.fit_transform(x_train[:,5])
z=pd.DataFrame(x_train)

z.to_csv('Mini.csv')

# %%
import pandas as pd
data=pd.read_csv('C:/Users/Deva Adithya/Downloads/Career project semi/Career project/Mini.csv',encoding='windows-1254')

# %%
data.tail()
# Out:
#          school             course  \
# 712  12th Board  12th Board - CBSE
# 713  12th Board  12th Board - ICSE
# 714  12th Board  12th Board - ICSE
# 715  12th Board  12th Board - ICSE
# 716  12th Board  12th Board - ICSE
#
#                                               group  \
# 712                    12th Board - CBSE - Commerce
# 713  12th Board - ICSE -  Select from Below Options
# 714                        12th Board - ICSE - Arts
# 715                     12th Board - ICSE - Science
# 716                    12th Board - ICSE - Commerce
#
#                                                 degree  \
# 712     12th Board - CBSE - Commerce - Aviation Course
# 713     12th Board - ICSE -  Select from Below Options
# 714  12th Board - ICSE - Arts -  Select from Below ...
# 715  12th Board - ICSE - Science -  Select from Bel...
# 716  12th Board - ICSE - Commerce -  Select from Be...
#
#                                                 branch  output
# 712  12th Board - CBSE - Commerce - Aviation Course...      56
# 713     12th Board - ICSE -  Select from Below Options      59
# 714  12th Board - ICSE - Arts -  Select from Below ...      60
# 715  12th Board - ICSE - Science -  Select from Bel...      62
# 716  12th Board - ICSE - Commerce -  Select from Be...      61

# %%
x=data.drop(columns='output')
y=data['output']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe1=OneHotEncoder()
ohe.fit(x[['school', 'course','group', 'degree','branch']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['10th Board', '12th Board'], dtype=object),
#  array(['10th Board -  Select from the Below Options', '10th Board - ITI',
#         '10th Board - Intermediate', '10th Board - ParaMedical',
#         '10th Board - Polytechnic',
#         '12th Board -  Select from the Below Options', '12th Board - CBSE',
#         '12th Board - ICSE'], dtype=object),
#  array(['10th Board -  Select from the Below Options',
#         '10th Board - ITI -  Select from the Below Options',
#         '10th Board - ITI - Civil',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA)',
#         '10th Board - ITI - Craftsman Food Production',
#         '10th Board - ITI - Electritian', '10th Board - ITI - Fitter',
#         '10th Board - ITI - Machine Tool Maintainance',
#         '10th Board - ITI - Mechanic',
#         '10th Board - ITI - Paint Technology',
#         '10th Board - ITI - Plumber', '10th Board - ITI - Welder',
#         '10th Board - Intermediate -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry)',
#         '10th Board - ParaMedical -  Select from Below Options',
#         '10th Board - ParaMedical - DMLT(Diploma in Medical Laboratory Technology)',
#         '10th Board - ParaMedical - Diploma in Dialysis Techniques',
#         '10th Board - ParaMedical - Diploma in Medical Record Technology',
#         '10th Board - ParaMedical - Diploma in OT Technician',
#         '10th Board - ParaMedical - Diploma in Orthopaedics',
#         '10th Board - ParaMedical - Diploma in Physiotherapy',
#         '10th Board - ParaMedical - Diploma in X-Ray Technology',
#         '10th Board - Polytechnic -  Select from Below Options',
#         '10th Board - Polytechnic - Automobile',
#         '10th Board - Polytechnic - Chemical',
#         '10th Board - Polytechnic - Civil',
#         '10th Board - Polytechnic - Computers',
#         '10th Board - Polytechnic - EEE',
#         '10th Board - Polytechnic - Electronic and Communication ',
#         '10th Board - Polytechnic - Information Technology',
#         '10th Board - Polytechnic - Mechanical',
#         '10th Board - Polytechnic - Metallurgical Engineering',
#         '10th Board - Polytechnic - Mining Engineering',
#         '10th Board - Polytechnic - Pharmacy',
#         '10th Board - Polytechnic - Textile Engineering',
#         '12th Board -  Select from the Below Options',
#         '12th Board - CBSE -  Select from Below Options',
#         '12th Board - CBSE - Arts', '12th Board - CBSE - Commerce',
#         '12th Board - CBSE - Science',
#         '12th Board - ICSE -  Select from Below Options',
#         '12th Board - ICSE - Arts', '12th Board - ICSE - Commerce',
#         '12th Board - ICSE - Science'], dtype=object),
#  array(['10th Board -  Select from the Below Options',
#         '10th Board - ITI -  Select from the Below Options',
#         '10th Board - ITI - Civil -  Select from the Below Options',
#         '10th Board - ITI - Civil - No Branches',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA) -   Select from the Below Options',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA) - No Branches',
#         '10th Board - ITI - Craftsman Food Production -  Select from the Below Options',
#         '10th Board - ITI - Craftsman Food Production - No Branches',
#         '10th Board - ITI - Electritian -  Select from the Below Options',
#         '10th Board - ITI - Electritian - No Branches',
#         '10th Board - ITI - Fitter -   Select from the Below Options',
#         '10th Board - ITI - Fitter - No Branches',
#         '10th Board - ITI - Machine Tool Maintainance -  Select from the Below Options',
#         '10th Board - ITI - Machine Tool Maintainance - No Branches',
#         '10th Board - ITI - Mechanic -  Select from the Below Options',
#         '10th Board - ITI - Mechanic - No Branches',
#         '10th Board - ITI - Paint Technology -  Select from the Below Options',
#         '10th Board - ITI - Paint Technology - No Branches',
#         '10th Board - ITI - Plumber -  Select from the Below Options',
#         '10th Board - ITI - Plumber - No Branches',
#         '10th Board - ITI - Welder -  Select from the Below Options',
#         '10th Board - ITI - Welder - No Branches',
#         '10th Board - Intermediate -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.EL.Ed(Bachelor of Elementary Education)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.P.Ed(Bachelor of Physical Education)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Sc (Bachelor of Science Courses)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BBS (Bachelor of Business Studies)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BCA (Bachelor of Computer Application)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BEM(bachelor of Event Manager)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BFA(Bachelor of Finance and Accounting)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BFD(Bachelor of Fashion Design)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BHM(Bachelor of Hotel Management)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BMM (Bachelor of Mass Media)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BMS(Bachelor of Management Science)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BSW(Bachelor of Social Work)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - CA (Chartered Accountancy)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - D.EL.Ed(Diploma in Elementary Education)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BBM(Bachelor of Business Management)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BCA (Bachelor of Computer Application)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BFA (Bachelor of Fine Arts)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BFT(Bachelor of Fashion Technology)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BHM & CT(Bachelor of Hotel management & Catering Tech)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BHRM(Bachelor of Human Resource Management)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Bachelor of Design',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) -  B.Sc (Bachelor of Science Courses)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) -  Bachelor of Arts',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Sc (Bachelor of Science Courses)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - BCA (Bachelor of Computer Application)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor in Finance and Accounting(BFA)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Finite Arts(BFA)',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Journalism and Mass Communication',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B F.Tech. (Bachelor of Fashion Technology)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B. Des. (Bachelor of Design)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Arch(Bachelor of Architecture)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.I.D (Bachelor of Interior Design)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Pharm (bachelor of pharmacy)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Plan(Bachelor of Planning)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - BCA (Bachelor of Computer Application)',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - BE/B.Tech',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - Merchant Navy course',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.F.Sc(Bachelor of Fisheries Sciences)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.Optom.(Bachelor of Optometry)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.Pharm (bachelor of pharmacy)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.Sc (Bachelor of Science)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.Sc.(Bachelor in Science)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.Sc.(Bachelor of Science)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.V.Sc (Bachelor of Veterinary Sciences)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.pharm(Bachelor of Pharmacy(Ayurveda))',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BAMS(Bachelor of Ayurvedic Medicine & Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BDS(Bachelor of Dental Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BHMS(Bachelor of Homeopathic Medicine&Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BNYS (Bachelor of Naturopathy&Yogic Sciences)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BOT(Bachelor of Occupational Therapy)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BPT(Bachelor of Physiotherapy)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BSMS(Bachelor of Siddha Medicine&Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - BUMS(Bachelor of Unani Medicine&Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - MBBS(Bachelor of Medicine& Bachelor of Surgery)',
#         '10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - Pharm.D.(Doctor of Pharmacy)',
#         '10th Board - ParaMedical -  Select from Below Options',
#         '10th Board - ParaMedical - DMLT(Diploma in Medical Laboratory Technology) -  Select from Below Options',
#         '10th Board - ParaMedical - DMLT(Diploma in Medical Laboratory Technology) - No Branches',
#         '10th Board - ParaMedical - Diploma in Dialysis Techniques -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in Dialysis Techniques - No Branches',
#         '10th Board - ParaMedical - Diploma in Medical Record Technology -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in Medical Record Technology - No Branches',
#         '10th Board - ParaMedical - Diploma in OT Technician -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in OT Technician - No Branches',
#         '10th Board - ParaMedical - Diploma in Orthopaedics -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in Orthopaedics - No Branches',
#         '10th Board - ParaMedical - Diploma in Physiotherapy -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in Physiotherapy - No Branches',
#         '10th Board - ParaMedical - Diploma in X-Ray Technology -  Select from Below Options',
#         '10th Board - ParaMedical - Diploma in X-Ray Technology - No Branches',
#         '10th Board - Polytechnic -  Select from Below Options',
#         '10th Board - Polytechnic - Automobile -  Select from Below Options',
#         '10th Board - Polytechnic - Automobile - BE/B.Tech',
#         '10th Board - Polytechnic - Chemical -  Select from Below Options',
#         '10th Board - Polytechnic - Chemical - BE/B.Tech',
#         '10th Board - Polytechnic - Civil -  Select from Below Options',
#         '10th Board - Polytechnic - Civil -BE/B.Tech',
#         '10th Board - Polytechnic - Computers -  Select from Below Options',
#         '10th Board - Polytechnic - Computers - BE/B.Tech',
#         '10th Board - Polytechnic - EEE -  Select from Below Options',
#         '10th Board - Polytechnic - EEE - BE/B.Tech',
#         '10th Board - Polytechnic - Electronic and Communication  -  Select from Below Options',
#         '10th Board - Polytechnic - Electronic and Communication - BE/B.Tech',
#         '10th Board - Polytechnic - Information Technology - BE/B.Tech',
#         '10th Board - Polytechnic - Mechanical -  Select from Below Options',
#         '10th Board - Polytechnic - Mechanical - BE/B.Tech',
#         '10th Board - Polytechnic - Metallurgical Engineering - BE/B.Tech',
#         '10th Board - Polytechnic - Mining Engineering - BE/B.Tech',
#         '10th Board - Polytechnic - Pharmacy -  Bachelor of Pharmacy (Ayurveda) ',
#         '10th Board - Polytechnic - Pharmacy - Bachelor of Pharmacy (B. Pharm) ',
#         '10th Board - Polytechnic - Pharmacy -Pharm (Hons.)',
#         '10th Board - Polytechnic - Textile Engineering - BE/B.Tech',
#         '12th Board -  Select from the Below Options',
#         '12th Board - CBSE -  Select from Below Options',
#         '12th Board - CBSE - Arts -  Select from Below Options',
#         '12th Board - CBSE - Arts - Aviation Course',
#         '12th Board - CBSE - Arts - B.B.A(Bachelors of Business Administration)',
#         '12th Board - CBSE - Arts - B.Sc.(Bachelor of Science)',
#         '12th Board - CBSE - Arts - BBS (Bachelor of Business Studies)',
#         '12th Board - CBSE - Arts - BEM (Bachelor of Event Management)',
#         '12th Board - CBSE - Arts - BFA (Bachelor of Fine Arts)',
#         '12th Board - CBSE - Arts - BFD (Bachelor of Fashion Designing)',
#         '12th Board - CBSE - Arts - BJMC (Bachelor of Journalism and Mass Communication)',
#         '12th Board - CBSE - Arts - BMS(Bachelor of Management Science)',
#         '12th Board - CBSE - Arts - BSW (Bachelor of Social Work)',
#         '12th Board - CBSE - Arts - BTTM (Bachelor of Travel and Tourism Management)',
#         '12th Board - CBSE - Arts - Bachelor of Arts',
#         '12th Board - CBSE - Arts - Bachelor of Design (B. Design)',
#         '12th Board - CBSE - Arts - Bachelor of Performing Arts',
#         '12th Board - CBSE - Arts - Integrated Law Course- BA + LL.B',
#         '12th Board - CBSE - Commerce -  Select from Below Options',
#         '12th Board - CBSE - Commerce - Aviation Course',
#         '12th Board - CBSE - Commerce - B.B.A(Bachelors of Business Administration)',
#         '12th Board - CBSE - Commerce - B.Com (Bachelor of Commerce)',
#         '12th Board - CBSE - Commerce - BA (Hons.) ',
#         '12th Board - CBSE - Commerce - Integrated Law Program',
#         '12th Board - CBSE - Science -  Select from Below Options',
#         '12th Board - CBSE - Science - Aviation Course',
#         '12th Board - CBSE - Science - B.Arch(Bachelor of Architecture)',
#         '12th Board - CBSE - Science - B.F.Sc(Bachelor of Fisheries Sciences)',
#         '12th Board - CBSE - Science - B.Optom.(Bachelor of Optometry)',
#         '12th Board - CBSE - Science - B.Pharm (bachelor of pharmacy)',
#         '12th Board - CBSE - Science - B.Sc (Bachelor of Science Courses)',
#         '12th Board - CBSE - Science - B.Sc (Bachelor of Science)',
#         '12th Board - CBSE - Science - B.Sc.(Bachelor in Science)',
#         '12th Board - CBSE - Science - B.Sc.(Bachelor of Science)',
#         '12th Board - CBSE - Science - B.V.Sc (Bachelor of Veterinary Sciences)',
#         '12th Board - CBSE - Science - B.pharm(Bachelor of Pharmacy(Ayurveda))',
#         '12th Board - CBSE - Science - BAMS(Bachelor of Ayurvedic Medicine & Surgery)',
#         '12th Board - CBSE - Science - BCA (Bachelor of Computer Application)',
#         '12th Board - CBSE - Science - BDS(Bachelor of Dental Surgery)',
#         '12th Board - CBSE - Science - BE/B.Tech',
#         '12th Board - CBSE - Science - BHMS(Bachelor of Homeopathic Medicine&Surgery)',
#         '12th Board - CBSE - Science - BNYS (Bachelor of Naturopathy&Yogic Sciences)',
#         '12th Board - CBSE - Science - BOT(Bachelor of Occupational Therapy)',
#         '12th Board - CBSE - Science - BPT(Bachelor of Physiotherapy)',
#         '12th Board - CBSE - Science - BPT- Bachelor of Physiotherapy',
#         '12th Board - CBSE - Science - BPharma- Bachelor of Pharmacy',
#         '12th Board - CBSE - Science - BSMS(Bachelor of Siddha Medicine&Surgery)',
#         '12th Board - CBSE - Science - BUMS(Bachelor of Unani Medicine&Surgery)',
#         '12th Board - CBSE - Science - MBBS(Bachelor of Medicine& Bachelor of Surgery)',
#         '12th Board - CBSE - Science - Pharm.D.(Doctor of Pharmacy)',
#         '12th Board - ICSE -  Select from Below Options',
#         '12th Board - ICSE - Arts -  Select from Below Options',
#         '12th Board - ICSE - Arts - Aviation Course',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration)',
#         '12th Board - ICSE - Arts - B.Sc.(Bachelor of Science)',
#         '12th Board - ICSE - Arts - BBS (Bachelor of Business Studies)',
#         '12th Board - ICSE - Arts - BEM (Bachelor of Event Management)',
#         '12th Board - ICSE - Arts - BFA (Bachelor of Fine Arts)',
#         '12th Board - ICSE - Arts - BFD (Bachelor of Fashion Designing)',
#         '12th Board - ICSE - Arts - BJMC (Bachelor of Journalism and Mass Communication)',
#         '12th Board - ICSE - Arts - BMS(Bachelor of Management Science)',
#         '12th Board - ICSE - Arts - BSW (Bachelor of Social Work)',
#         '12th Board - ICSE - Arts - BTTM (Bachelor of Travel and Tourism Management)',
#         '12th Board - ICSE - Arts - Bachelor of Arts',
#         '12th Board - ICSE - Arts - Bachelor of Design (B. Design)',
#         '12th Board - ICSE - Arts - Bachelor of Performing Arts',
#         '12th Board - ICSE - Arts - Integrated Law Course- BA + LL.B',
#         '12th Board - ICSE - Commerce -  Select from Below Options',
#         '12th Board - ICSE - Commerce - Aviation Course',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration)',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce)',
#         '12th Board - ICSE - Commerce - BA (Hons.) ',
#         '12th Board - ICSE - Commerce - Integrated Law Program',
#         '12th Board - ICSE - Science -  Select from Below Options',
#         '12th Board - ICSE - Science - Aviation Course',
#         '12th Board - ICSE - Science - B.Arch(Bachelor of Architecture)',
#         '12th Board - ICSE - Science - B.F.Sc(Bachelor of Fisheries Sciences)',
#         '12th Board - ICSE - Science - B.Optom.(Bachelor of Optometry)',
#         '12th Board - ICSE - Science - B.Pharm (bachelor of pharmacy)',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses)',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science)',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor in Science)',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor of Science)',
#         '12th Board - ICSE - Science - B.V.Sc (Bachelor of Veterinary Sciences)',
#         '12th Board - ICSE - Science - B.pharm(Bachelor of Pharmacy(Ayurveda))',
#         '12th Board - ICSE - Science - BAMS(Bachelor of Ayurvedic Medicine & Surgery)',
#         '12th Board - ICSE - Science - BCA (Bachelor of Computer Application)',
#         '12th Board - ICSE - Science - BDS(Bachelor of Dental Surgery)',
#         '12th Board - ICSE - Science - BE/B.Tech',
#         '12th Board - ICSE - Science - BHMS(Bachelor of Homeopathic Medicine&Surgery)',
#         '12th Board - ICSE - Science - BNYS (Bachelor of Naturopathy&Yogic Sciences)',
#         '12th Board - ICSE - Science - BOT(Bachelor of Occupational Therapy)',
#         '12th Board - ICSE - Science - BPT(Bachelor of Physiotherapy)',
#         '12th Board - ICSE - Science - BPT- Bachelor of Physiotherapy',
#         '12th Board - ICSE - Science - BPharma- Bachelor of Pharmacy',
#         '12th Board - ICSE - Science - BSMS(Bachelor of Siddha Medicine&Surgery)',
#         '12th Board - ICSE - Science - BUMS(Bachelor of Unani Medicine&Surgery)',
#         '12th Board - ICSE - Science - MBBS(Bachelor of Medicine& Bachelor of Surgery)',
#         '12th Board - ICSE - Science - Pharm.D.(Doctor of Pharmacy)'],
#        dtype=object),
#  array([' 12th Board - CBSE - Science - B.Sc.(Bachelor in Science) - Sericulture',
#         '10th Board -  Select from the Below Options',
#         '10th Board - ITI -  Select from the Below Options',
#         '10th Board - ITI - Civil -  Select from the Below Options',
#         '10th Board - ITI - Civil - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Civil - No Branches - No Branches',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA) -   Select from the Below Options',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA) - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Computer Operator and programming Assistant (COPA) - No Branches - No Branches',
#         '10th Board - ITI - Craftsman Food Production -  Select from the Below Options',
#         '10th Board - ITI - Craftsman Food Production - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Craftsman Food Production - No Branches - No Branches',
#         '10th Board - ITI - Electrician - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Electrician - No Branches - No Branches',
#         '10th Board - ITI - Electritian -  Select from the Below Options',
#         '10th Board - ITI - Fitter -   Select from the Below Options',
#         '10th Board - ITI - Fitter - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Fitter - No Branches - No Branches',
#         '10th Board - ITI - Machine Tool Maintainance -  Select from the Below Options',
#         '10th Board - ITI - Machine Tool Maintainance - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Machine Tool Maintainance - No Branches - No Branches',
#         '10th Board - ITI - Mechanic -  Select from the Below Options',
#         '10th Board - ITI - Mechanic - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Mechanic - No Branches - No Branches',
#         '10th Board - ITI - Paint Technology -  Select from the Below Options',
#         '10th Board - ITI - Paint Technology - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Paint Technology - No Branches - No Branches',
#         '10th Board - ITI - Plumber -  Select from the Below Options',
#         '10th Board - ITI - Plumber - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Plumber - No Branches - No Branches',
#         '10th Board - ITI - Welder -  Select from the Below Options',
#         '10th Board - ITI - Welder - No Branches -  Select from the Below Options',
#         '10th Board - ITI - Welder - No Branches - No Branches',
#         '10th Board - Intermediate -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) -  Select from Below Options',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Banking and Insurance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Communication and Media Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Foreign Trade',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospital and Healthcare Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospitality and Hotel Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Human Resource',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Information Technology',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Marketing Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Finance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Logistics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Sports Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Travel and Tourism Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - B.Com+LLB(Bachelor of Legislative Law)',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Accountancy',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Accounting',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Accounting and Finance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Applied Economics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Banking Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Banking and Finance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Banking and Insurance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Business Administration',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Business Economics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Capital Market',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Computer Applications',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Computer Science',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Corporate Secretaryship',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom E-Commerce',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Economics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Finance',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Financial Accounting',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Financial Markets',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Foreign Trade Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Insurance Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Management Studies',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Marketing',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Professional',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Statistics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Supply Chain Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Tax Procedure and Practice',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Taxation',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Com (Bachelor of Commerce) - BCom Tourism and Travel Management',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.EL.Ed(Bachelor of Elementary Education) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.P.Ed(Bachelor of Physical Education) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Sc (Bachelor of Science Courses) - Animation and Multimedia',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Sc (Bachelor of Science Courses) - BSc Maths',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - B.Sc (Bachelor of Science Courses) - BSc Statistics',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BBS (Bachelor of Business Studies) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BCA (Bachelor of Computer Application) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BEM(bachelor of Event Manager) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BFA(Bachelor of Finance and Accounting) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BFD(Bachelor of Fashion Design) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BHM(Bachelor of Hotel Management) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BMM (Bachelor of Mass Media) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BMS(Bachelor of Management Science) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - BSW(Bachelor of Social Work) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - CA (Chartered Accountancy) - No Branches',
#         '10th Board - Intermediate - CEC(Commerce, Economics, Civics) - D.EL.Ed(Diploma in Elementary Education) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) -  Select from Below Options',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Banking and Insurance',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Communication and Media Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Foreign Trade',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospital and Healthcare Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospitality and Hotel Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Human Resource',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Information Technology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A  Marketing Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Finance',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Logistics',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Sports Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - B.B.A(Bachelors of Business Administration) - B.B.A Travel and Tourism Management',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts)  - BA in History',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Anthropology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Archaeology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Astrology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Criminology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Economics',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Geography',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Journalism',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Multimedia',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Philosophy',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Political Science',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Psychology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Public Administration',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Social Work',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Sociology',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Statistics',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BA(Bachelor of Arts) - BA in Tourism',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BBM(Bachelor of Business Management) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BCA (Bachelor of Computer Application) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BFA (Bachelor of Fine Arts) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BFT(Bachelor of Fashion Technology) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BHM & CT(Bachelor of Hotel management & Catering Tech) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - BHRM(Bachelor of Human Resource Management) - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Bachelor of Design - No Branches',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course - B.El.Ed.(Bachelor of Elementary Education)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course - BA + B.Ed(Bachelor of Arts and Bachelor of Education)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course - BA + LLB(Bachelor of Arts and Bachelor of Legislative Law)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course - BA+ MA (Bachelor of Arts+ Master of Arts)',
#         '10th Board - Intermediate - HEC(History, Economics,  Civics) - Double Degree Integrated Course - BBA+MBA',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) -  B.Sc (Bachelor of Science Courses) - BSc Geography',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Banking and Insurance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Communication and Media Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Foreign Trade',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospital and Healthcare Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Hospitality and Hotel Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Human Resource',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Information Technology',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A  Marketing Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A Finance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A Logistics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A Sports Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.B.A(Bachelors of Business Administration) - B.B.A Travel and Tourism Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Accountancy',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Accounting',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Accounting and Finance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Applied Economics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Banking Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Banking and Finance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Banking and Insurance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Business Administration',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Business Economics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Capital Market',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Computer Applications',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Computer Science',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Corporate Secretaryship',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom E-Commerce',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Economics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Finance',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Financial Accounting',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Financial Markets',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Foreign Trade Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Insurance Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Management Studies',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Marketing',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Professional',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Statistics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Supply Chain Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Tax Procedure and Practice',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Taxation',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - BCom Tourism and Travel Management',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Com (Bachelor of Commerce) - No Branches',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Sc (Bachelor of Science Courses) -  Select from Below Options',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Sc (Bachelor of Science Courses) - BSc Fashion Designer',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Sc (Bachelor of Science Courses) - BSc Interior Designer',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - B.Sc (Bachelor of Science Courses) - BSc Social Sciences',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in Economics',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in English Literature',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in History',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in Maths',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in Political Science',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Arts - BA in Sociology',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Finite Arts(BFA) - No Branches',
#         '10th Board - Intermediate - MEC(Maths, Economics, Commerce) - Bachelor of Journalism and Mass Communication - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B F.Tech. (Bachelor of Fashion Technology) - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B. Des. (Bachelor of Design) - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Arch(Bachelor of Architecture) - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.I.D (Bachelor of Interior Design) - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Pharm (bachelor of pharmacy) - No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Plan(Bachelor of Planning)- No Branches',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Aeronautics',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Agriculture',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Animation',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Applied Electronics',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Aviation',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - B.Sc Nautical Science',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Chemistry',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Computer Science',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Electronics and Communication',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Film Making',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Forestry',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Geography',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Geology',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Hotel Management',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Information Technology',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Maths',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Physics',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Product Design',
#         '10th Board - Intermediate - MPC(Maths, Physics, and Chemistry) - B.Sc (Bachelor of Science Courses) - Statistics',
# ...
#         '12th Board - CBSE - Science - Pharm.D.(Doctor of Pharmacy) - No Branches',
#         '12th Board - ICSE -  Select from Below Options',
#         '12th Board - ICSE - Arts -  Select from Below Options',
#         '12th Board - ICSE - Arts - Aviation Course - BBA in Airport Management',
#         '12th Board - ICSE - Arts - Aviation Course - BBA in Aviation',
#         '12th Board - ICSE - Arts - Aviation Course - BSc in Airline and Airport Management',
#         '12th Board - ICSE - Arts - Aviation Course - Diploma in Airfare and Ticketing Management',
#         '12th Board - ICSE - Arts - Aviation Course - Diploma in Airport Management',
#         '12th Board - ICSE - Arts - Aviation Course - Diploma in Aviation Hospitality',
#         '12th Board - ICSE - Arts - Aviation Course - Diploma in Ground Staff and Cabin Crew Training',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Banking and Insurance',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Communication and Media Management',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Foreign Trade',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Hospital and Healthcare Management',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Hospitality and Hotel Management',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Human Resource',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Information Technology',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A  Marketing Management',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A Finance',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A Logistics',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A Sports Management',
#         '12th Board - ICSE - Arts - B.B.A(Bachelors of Business Administration) - B.B.A Travel and Tourism Management',
#         '12th Board - ICSE - Arts - B.Sc.(Bachelor of Science) - Hospitality and Hotel Administration',
#         '12th Board - ICSE - Arts - B.Sc.(Bachelor of Science) - Interior Design',
#         '12th Board - ICSE - Arts - BBS (Bachelor of Business Studies) - No Branches',
#         '12th Board - ICSE - Arts - BEM (Bachelor of Event Management) - No Branches',
#         '12th Board - ICSE - Arts - BFA (Bachelor of Fine Arts) - No Branches',
#         '12th Board - ICSE - Arts - BFD (Bachelor of Fashion Designing) - No Branches',
#         '12th Board - ICSE - Arts - BJMC (Bachelor of Journalism and Mass Communication) - No Branches',
#         '12th Board - ICSE - Arts - BMS(Bachelor of Management Science) - No Branches',
#         '12th Board - ICSE - Arts - BSW (Bachelor of Social Work) - No Branches',
#         '12th Board - ICSE - Arts - BTTM (Bachelor of Travel and Tourism Management) - No Branches',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Anthropology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Archaeology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Astrology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Criminology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Economics',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Geography',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Journalism',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Multimedia',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Philosophy',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Political Science',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Psychology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Public Administration',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Social Work',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Sociology',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Statistics',
#         '12th Board - ICSE - Arts - Bachelor of Arts - BA in Tourism',
#         '12th Board - ICSE - Arts - Bachelor of Design (B. Design) - No Branches',
#         '12th Board - ICSE - Arts - Bachelor of Performing Arts - No Branches',
#         '12th Board - ICSE - Arts - Integrated Law Course- BA + LL.B - No Branches',
#         '12th Board - ICSE - Commerce -  Select from Below Options',
#         '12th Board - ICSE - Commerce - Aviation Course - BBA in Airport Management',
#         '12th Board - ICSE - Commerce - Aviation Course - BBA in Aviation',
#         '12th Board - ICSE - Commerce - Aviation Course - BSc in Airline and Airport Management',
#         '12th Board - ICSE - Commerce - Aviation Course - Diploma in Airfare and Ticketing Management',
#         '12th Board - ICSE - Commerce - Aviation Course - Diploma in Airport Management',
#         '12th Board - ICSE - Commerce - Aviation Course - Diploma in Aviation Hospitality',
#         '12th Board - ICSE - Commerce - Aviation Course - Diploma in Ground Staff and Cabin Crew Training',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Banking and Insurance',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Communication and Media Management',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Foreign Trade',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Hospital and Healthcare Management',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Hospitality and Hotel Management',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Human Resource',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Information Technology',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A  Marketing Management',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A Finance',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A Logistics',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A Sports Management',
#         '12th Board - ICSE - Commerce - B.B.A(Bachelors of Business Administration) - B.B.A Travel and Tourism Management',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Accountancy',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Accounting',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Accounting and Finance',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Applied Economics',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Banking Management',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Banking and Finance',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Banking and Insurance',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Business Administration',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Business Economics',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Capital Market',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Computer Applications',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Computer Science',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Corporate Secretaryship',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom E-Commerce',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Economics',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Finance',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Financial Accounting',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Financial Markets',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Foreign Trade Management',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Insurance Management',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Management Studies',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Marketing',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Professional',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Statistics',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Supply Chain Management',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Tax Procedure and Practice',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Taxation',
#         '12th Board - ICSE - Commerce - B.Com (Bachelor of Commerce) - BCom Tourism and Travel Management',
#         '12th Board - ICSE - Commerce - BA (Hons.) - Economics',
#         '12th Board - ICSE - Commerce - Integrated Law Program - B.Com+LLB(Bachelor of Commerce - Bachelor of Legislative Law)',
#         '12th Board - ICSE - Commerce - Integrated Law Program - BBA+LLB(Bachelor of Business Administration + Bachelor of Laws)',
#         '12th Board - ICSE - Science -  Select from Below Options',
#         '12th Board - ICSE - Science - Aviation Course - Aeronautical Engineering',
#         '12th Board - ICSE - Science - Aviation Course - Aircraft maintenance Engineering (AME)',
#         '12th Board - ICSE - Science - Aviation Course - B.Sc Aviation',
#         '12th Board - ICSE - Science - Aviation Course - BBA in Airport Management',
#         '12th Board - ICSE - Science - Aviation Course - BBA in Aviation',
#         '12th Board - ICSE - Science - Aviation Course - BSc in Airline and Airport Management',
#         '12th Board - ICSE - Science - Aviation Course - Commercial Pilot Training',
#         '12th Board - ICSE - Science - Aviation Course - Diploma in Airfare and Ticketing Management',
#         '12th Board - ICSE - Science - Aviation Course - Diploma in Airport Management',
#         '12th Board - ICSE - Science - Aviation Course - Diploma in Aviation Hospitality',
#         '12th Board - ICSE - Science - Aviation Course - Diploma in Ground Staff and Cabin Crew Training',
#         '12th Board - ICSE - Science - B.Arch(Bachelor of Architecture) - No Branches',
#         '12th Board - ICSE - Science - B.F.Sc(Bachelor of Fisheries Sciences) - No Branches',
#         '12th Board - ICSE - Science - B.Optom.(Bachelor of Optometry) - No Branches',
#         '12th Board - ICSE - Science - B.Pharm (bachelor of pharmacy) - No Branches',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - Animation and Multimedia',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - BSc Chemistry',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - BSc Geology',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - BSc Information Technology',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - BSc Maths',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science Courses) - BSc Physics',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science) - BSc Nursing',
#         '12th Board - ICSE - Science - B.Sc (Bachelor of Science) - Trauma Care Management',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor in Science) - Sericulture',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor of Science) - Agriculture',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor of Science) - Interior Design',
#         '12th Board - ICSE - Science - B.Sc.(Bachelor of Science) - Nutrition & Dietetics',
#         '12th Board - ICSE - Science - B.V.Sc (Bachelor of Veterinary Sciences) - No Branches',
#         '12th Board - ICSE - Science - B.pharm(Bachelor of Pharmacy(Ayurveda)) - No Branches',
#         '12th Board - ICSE - Science - BAMS(Bachelor of Ayurvedic Medicine & Surgery) - No Branches',
#         '12th Board - ICSE - Science - BCA (Bachelor of Computer Application) - No Branches',
#         '12th Board - ICSE - Science - BDS(Bachelor of Dental Surgery) - No Branches',
#         '12th Board - ICSE - Science - BE/B.Tech - Aeronautical Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Automation and Robotics',
#         '12th Board - ICSE - Science - BE/B.Tech - Automobile Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Biotechnology Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Ceramic Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Chemical Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Civil Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Artificial Intelligence and Machine Learning)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Blockchain)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Cloud Computing)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Cyber Security)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Data Science)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Digital Transformation)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(Specialization in Robotics)',
#         '12th Board - ICSE - Science - BE/B.Tech - Computer Science and Engineering(System and Network Administration)',
#         '12th Board - ICSE - Science - BE/B.Tech - Construction Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Electrical and Electronics Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Electronics and Communication Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Instrumentation Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Petroleum Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Robotics Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Smart Manufacturing & Automation',
#         '12th Board - ICSE - Science - BE/B.Tech - Structural Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Textile Engineering',
#         '12th Board - ICSE - Science - BE/B.Tech - Transportation Engineering',
#         '12th Board - ICSE - Science - BHMS(Bachelor of Homeopathic Medicine&Surgery) - No Branches',
#         '12th Board - ICSE - Science - BNYS (Bachelor of Naturopathy&Yogic Sciences) - No Branches',
#         '12th Board - ICSE - Science - BOT(Bachelor of Occupational Therapy) - No Branches',
#         '12th Board - ICSE - Science - BPT(Bachelor of Physiotherapy) - No Branches',
#         '12th Board - ICSE - Science - BPT- Bachelor of Physiotherapy - No Branches',
#         '12th Board - ICSE - Science - BPharma- Bachelor of Pharmacy - No Branches',
#         '12th Board - ICSE - Science - BSMS(Bachelor of Siddha Medicine&Surgery) - No Branches',
#         '12th Board - ICSE - Science - BUMS(Bachelor of Unani Medicine&Surgery) - No Branches',
#         '12th Board - ICSE - Science - MBBS(Bachelor of Medicine& Bachelor of Surgery) - No Branches',
#         '12th Board - ICSE - Science - Pharm.D.(Doctor of Pharmacy) - No Branches'],
#        dtype=object)]

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['school', 'course','group', 'degree','branch']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['10th Board', '12th Board'], dtype=object),
#                                                                             array(['10th Board -  Select from the Below Options', '10th Board - ITI',
#        '10th Board - Intermediate', '10th Board - ParaMedical',
#        '10th Board - Polytechnic',
#        '12th Board -  Select from the Below Optio...
#        '12th Board - ICSE - Science - BSMS(Bachelor of Siddha Medicine&Surgery) - No Branches',
#        '12th Board - ICSE - Science - BUMS(Bachelor of Unani Medicine&Surgery) - No Branches',
#        '12th Board - ICSE - Science - MBBS(Bachelor of Medicine& Bachelor of Surgery) - No Branches',
#        '12th Board - ICSE - Science - Pharm.D.(Doctor of Pharmacy) - No Branches'],
#       dtype=object)]),
#                                                   ['school', 'course', 'group',
#                                                    'degree', 'branch'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4001319718290748

# %%
scores=[]
for i in range(2500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
import numpy as np
np.argmax(scores)
# Out:
# 1209

# %%
scores[np.argmax(scores)]
# Out:
# 0.741208816361702

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.741208816361702

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
prediction=pipe.predict(pd.DataFrame([['10th Board','10th Board - Intermediate','10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry)','10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.pharm(Bachelor of Pharmacy(Ayurveda))','10th Board - Intermediate -BiPC( Biology, Physics ,Chemistry) - B.pharm(Bachelor of Pharmacy(Ayurveda)) - No Branches']],columns=['school', 'course','group', 'degree','branch']))
print(prediction)
# Out:
# [139.00000003]

# %%
import math
import numpy as np
prediction=math.floor(prediction)

print(int(prediction))
# Out:
# 139

# %%
df=pd.read_csv('C:/Users/Deva Adithya/Downloads/Career project semi/Career project/output.csv')
df
# Out:
#       in                                                out
# 0    225  Jobs: Racing Car Designer, Flight Mechanics En...
# 1    150  Jobs: Executive and Managerial Positions, Driv...
# 2    114  Jobs: Civil Engineer, Transportation Engineer,...
# 3    278  Jobs: data scientist, computer programmer, sys...
# 4    129  Jobs: Data scientist, Data Architect, Data Sci...
# ..   ...                                                ...
# 712   56  12th Board - CBSE - Commerce - Aviation Course...
# 713   59     12th Board - ICSE -  Select from Below Options
# 714   60  12th Board - ICSE - Arts -  Select from Below ...
# 715   62  12th Board - ICSE - Science -  Select from Bel...
# 716   61  12th Board - ICSE - Commerce -  Select from Be...
#
# [717 rows x 2 columns]

# %%
df2=df.loc[df['in'] == prediction, 'out'].iloc[0]
print(df2)
# Out:
# Jobs: Drug inspector, Pharmacist,Pharmaceutical marketing, Pathological lab scientist, Health inspector, Chemical/drug technician, Medical devices and quality control manufacturing, Medical Underwriter
# Salary:3.5 LPA
# Higher Education: M Pharm Ayurveda

# %%
prediction=pipe.predict(pd.DataFrame([['12th Board','12th Board - CBSE','12th Board - ICSE - Science','12th Board - CBSE - Science - BE/B.Tech','12th Board - CBSE - Science - BE/B.Tech - Electronics and Communication Engineering']],columns=['school', 'course','group', 'degree','branch']))
print(prediction)
# Out:
# [144.12046297]

# %%
import math
prediction=math.floor(prediction)
print(prediction)
df2=df.loc[df['in'] == prediction, 'out'].iloc[0]
print(df2)
# Out:
# 144
# Jobs: Electrical Manager, Maintenance Engineer, Professor, Mechanical Engineer
# Salary:3.6 - 6.5 LPA
# Higher Education: MTech, ME, MBA
